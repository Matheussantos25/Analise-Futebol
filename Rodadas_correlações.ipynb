# %%
import pandas as pd
dados = pd.read_csv("C:\\Users\\msdof\\OneDrive\\Imagens\\Ligas\\BRA.csv")
dados_2023 = dados[dados['Season'] == 2023]
dados_2023
# Out:
#      Country   League  Season        Date   Time           Home         Away  \
# 4180  Brazil  Serie A    2023  15/04/2023  20:00     America MG   Fluminense
# 4181  Brazil  Serie A    2023  15/04/2023  20:00      Palmeiras       Cuiaba
# 4182  Brazil  Serie A    2023  15/04/2023  22:30   Athletico-PR        Goias
# 4183  Brazil  Serie A    2023  15/04/2023  22:30    Botafogo RJ    Sao Paulo
# 4184  Brazil  Serie A    2023  15/04/2023  22:30     Bragantino        Bahia
# ...      ...      ...     ...         ...    ...            ...          ...
# 4555  Brazil  Serie A    2023  07/12/2023  00:30     Fluminense       Gremio
# 4556  Brazil  Serie A    2023  07/12/2023  00:30  Internacional  Botafogo RJ
# 4557  Brazil  Serie A    2023  07/12/2023  00:30         Santos    Fortaleza
# 4558  Brazil  Serie A    2023  07/12/2023  00:30      Sao Paulo  Flamengo RJ
# 4559  Brazil  Serie A    2023  07/12/2023  00:30          Vasco   Bragantino
#
#        HG   AG Res    PH    PD    PA  MaxH  MaxD  MaxA  AvgH  AvgD  AvgA
# 4180  0.0  3.0   A  2.55  3.34  2.98  2.69  3.39  2.98  2.49  3.23  2.87
# 4181  2.0  1.0   H  1.39  5.12  8.51  1.40  5.30  9.75  1.35  4.92  8.54
# 4182  2.0  0.0   H  1.64  3.69  6.64  1.67  3.75  6.75  1.62  3.57  6.17
# 4183  2.0  1.0   H  2.46  3.17  3.26  2.55  3.26  3.38  2.40  3.05  3.15
# 4184  2.0  1.0   H  1.85  3.71  4.58  1.91  3.80  4.58  1.84  3.56  4.21
# ...   ...  ...  ..   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 4555  2.0  3.0   A  2.08  3.92  3.35  2.16  3.96  3.45  2.08  3.75  3.23
# 4556  3.0  1.0   H  2.10  3.38  3.71  2.18  3.51  3.86  2.09  3.36  3.56
# 4557  1.0  2.0   A  1.95  3.33  4.50  1.98  3.47  4.60  1.94  3.28  4.23
# 4558  1.0  0.0   H  3.41  3.36  2.26  3.56  3.46  2.34  3.35  3.28  2.21
# 4559  2.0  1.0   H  2.21  3.35  3.54  2.28  3.49  3.75  2.18  3.31  3.38
#
# [380 rows x 19 columns]

# %%
# Copiar o data frame
dados_2023 = dados_2023.copy()

# %%
dados_2023['Rodada'] = (dados_2023.index - dados_2023.index[0]) // 10 + 1
dados_2023
# Out:
#      Country   League  Season        Date   Time           Home         Away  \
# 4180  Brazil  Serie A    2023  15/04/2023  20:00     America MG   Fluminense
# 4181  Brazil  Serie A    2023  15/04/2023  20:00      Palmeiras       Cuiaba
# 4182  Brazil  Serie A    2023  15/04/2023  22:30   Athletico-PR        Goias
# 4183  Brazil  Serie A    2023  15/04/2023  22:30    Botafogo RJ    Sao Paulo
# 4184  Brazil  Serie A    2023  15/04/2023  22:30     Bragantino        Bahia
# ...      ...      ...     ...         ...    ...            ...          ...
# 4555  Brazil  Serie A    2023  07/12/2023  00:30     Fluminense       Gremio
# 4556  Brazil  Serie A    2023  07/12/2023  00:30  Internacional  Botafogo RJ
# 4557  Brazil  Serie A    2023  07/12/2023  00:30         Santos    Fortaleza
# 4558  Brazil  Serie A    2023  07/12/2023  00:30      Sao Paulo  Flamengo RJ
# 4559  Brazil  Serie A    2023  07/12/2023  00:30          Vasco   Bragantino
#
#        HG   AG Res    PH    PD    PA  MaxH  MaxD  MaxA  AvgH  AvgD  AvgA  \
# 4180  0.0  3.0   A  2.55  3.34  2.98  2.69  3.39  2.98  2.49  3.23  2.87
# 4181  2.0  1.0   H  1.39  5.12  8.51  1.40  5.30  9.75  1.35  4.92  8.54
# 4182  2.0  0.0   H  1.64  3.69  6.64  1.67  3.75  6.75  1.62  3.57  6.17
# 4183  2.0  1.0   H  2.46  3.17  3.26  2.55  3.26  3.38  2.40  3.05  3.15
# 4184  2.0  1.0   H  1.85  3.71  4.58  1.91  3.80  4.58  1.84  3.56  4.21
# ...   ...  ...  ..   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 4555  2.0  3.0   A  2.08  3.92  3.35  2.16  3.96  3.45  2.08  3.75  3.23
# 4556  3.0  1.0   H  2.10  3.38  3.71  2.18  3.51  3.86  2.09  3.36  3.56
# 4557  1.0  2.0   A  1.95  3.33  4.50  1.98  3.47  4.60  1.94  3.28  4.23
# 4558  1.0  0.0   H  3.41  3.36  2.26  3.56  3.46  2.34  3.35  3.28  2.21
# 4559  2.0  1.0   H  2.21  3.35  3.54  2.28  3.49  3.75  2.18  3.31  3.38
#
#       Rodada
# 4180       1
# 4181       1
# 4182       1
# 4183       1
# 4184       1
# ...      ...
# 4555      38
# 4556      38
# 4557      38
# 4558      38
# 4559      38
#
# [380 rows x 20 columns]

# %%
dados_2023['Placar'] = dados_2023['HG'].astype(str) + '-' + dados_2023['AG'].astype(str)
dados_2023
# Out:
#      Country   League  Season        Date   Time           Home         Away  \
# 4180  Brazil  Serie A    2023  15/04/2023  20:00     America MG   Fluminense
# 4181  Brazil  Serie A    2023  15/04/2023  20:00      Palmeiras       Cuiaba
# 4182  Brazil  Serie A    2023  15/04/2023  22:30   Athletico-PR        Goias
# 4183  Brazil  Serie A    2023  15/04/2023  22:30    Botafogo RJ    Sao Paulo
# 4184  Brazil  Serie A    2023  15/04/2023  22:30     Bragantino        Bahia
# ...      ...      ...     ...         ...    ...            ...          ...
# 4555  Brazil  Serie A    2023  07/12/2023  00:30     Fluminense       Gremio
# 4556  Brazil  Serie A    2023  07/12/2023  00:30  Internacional  Botafogo RJ
# 4557  Brazil  Serie A    2023  07/12/2023  00:30         Santos    Fortaleza
# 4558  Brazil  Serie A    2023  07/12/2023  00:30      Sao Paulo  Flamengo RJ
# 4559  Brazil  Serie A    2023  07/12/2023  00:30          Vasco   Bragantino
#
#        HG   AG Res  ...    PD    PA  MaxH  MaxD  MaxA  AvgH  AvgD  AvgA  \
# 4180  0.0  3.0   A  ...  3.34  2.98  2.69  3.39  2.98  2.49  3.23  2.87
# 4181  2.0  1.0   H  ...  5.12  8.51  1.40  5.30  9.75  1.35  4.92  8.54
# 4182  2.0  0.0   H  ...  3.69  6.64  1.67  3.75  6.75  1.62  3.57  6.17
# 4183  2.0  1.0   H  ...  3.17  3.26  2.55  3.26  3.38  2.40  3.05  3.15
# 4184  2.0  1.0   H  ...  3.71  4.58  1.91  3.80  4.58  1.84  3.56  4.21
# ...   ...  ...  ..  ...   ...   ...   ...   ...   ...   ...   ...   ...
# 4555  2.0  3.0   A  ...  3.92  3.35  2.16  3.96  3.45  2.08  3.75  3.23
# 4556  3.0  1.0   H  ...  3.38  3.71  2.18  3.51  3.86  2.09  3.36  3.56
# 4557  1.0  2.0   A  ...  3.33  4.50  1.98  3.47  4.60  1.94  3.28  4.23
# 4558  1.0  0.0   H  ...  3.36  2.26  3.56  3.46  2.34  3.35  3.28  2.21
# 4559  2.0  1.0   H  ...  3.35  3.54  2.28  3.49  3.75  2.18  3.31  3.38
#
#       Rodada   Placar
# 4180       1  0.0-3.0
# 4181       1  2.0-1.0
# 4182       1  2.0-0.0
# 4183       1  2.0-1.0
# 4184       1  2.0-1.0
# ...      ...      ...
# 4555      38  2.0-3.0
# 4556      38  3.0-1.0
# 4557      38  1.0-2.0
# 4558      38  1.0-0.0
# 4559      38  2.0-1.0
#
# [380 rows x 21 columns]

# %% [markdown]
# Hipótese de que determinado repetir um placar em casa na rodada seguinte é pouco provável

# %%
# Agrupando os dados por time da casa e rodada, depois shiftando os placares para comparar com a próxima rodada
dados_2023['Placar_Proxima_Rodada'] = dados_2023.groupby('Home')['Placar'].shift(-1)

# Calculando os casos em que o placar se repete
dados_2023['Placar_Repetido'] = dados_2023['Placar'] == dados_2023['Placar_Proxima_Rodada']

# Probabilidade de um time repetir o mesmo placar na rodada seguinte
probabilidade_repetir_placar = dados_2023['Placar_Repetido'].mean() * 100
probabilidade_repetir_placar
# Out:
# 9.736842105263158

# %% [markdown]
# Testando Jogos desta Hipótese

# %%
# Encontrando os jogos seguintes onde o placar se repetiu
jogos_placar_repetido_com_proximo = dados_2023[dados_2023['Placar_Repetido']].copy()

# Adicionando informações do jogo seguinte
jogos_placar_repetido_com_proximo['Data_Proximo_Jogo'] = jogos_placar_repetido_com_proximo.groupby('Home')['Date'].shift(-1)
jogos_placar_repetido_com_proximo['Adversario_Proximo_Jogo'] = jogos_placar_repetido_com_proximo.groupby('Home')['Away'].shift(-1)
jogos_placar_repetido_com_proximo['Placar_Proximo_Jogo'] = jogos_placar_repetido_com_proximo.groupby('Home')['Placar'].shift(-1)

# %%
# Selecionando apenas os jogos onde o placar do próximo jogo é o mesmo
jogos_iguais_com_proximo = jogos_placar_repetido_com_proximo[jogos_placar_repetido_com_proximo['Placar'] == jogos_placar_repetido_com_proximo['Placar_Proximo_Jogo']]

# Exibindo os jogos
jogos_iguais_com_proximo = jogos_iguais_com_proximo[['Season', 'Rodada', 'Date', 'Home', 'Away', 'Placar', 'Data_Proximo_Jogo', 'Adversario_Proximo_Jogo', 'Placar_Proximo_Jogo']]
jogos_iguais_com_proximo
# Out:
#       Season  Rodada        Date         Home         Away   Placar  \
# 4249    2023       7  23/05/2023     Cruzeiro       Cuiaba  0.0-1.0
# 4259    2023       8  28/05/2023  Botafogo RJ   America MG  2.0-0.0
# 4274    2023      10  11/06/2023  Botafogo RJ    Fortaleza  2.0-0.0
# 4365    2023      19  14/08/2023    Palmeiras     Cruzeiro  1.0-0.0
# 4386    2023      21  27/08/2023    Palmeiras        Vasco  1.0-0.0
# 4432    2023      26  08/10/2023  Corinthians  Flamengo RJ  1.0-1.0
#
#      Data_Proximo_Jogo Adversario_Proximo_Jogo Placar_Proximo_Jogo
# 4249        03/06/2023             Atletico-MG             0.0-1.0
# 4259        11/06/2023               Fortaleza             2.0-0.0
# 4274        02/07/2023                   Vasco             2.0-0.0
# 4365        27/08/2023                   Vasco             1.0-0.0
# 4386        28/10/2023                   Bahia             1.0-0.0
# 4432        22/10/2023              America MG             1.0-1.0

# %%
# Contando o número de jogos onde o placar se repetiu no próximo jogo
numero_jogos_placar_repetido = jogos_iguais_com_proximo.shape[0]
numero_jogos_placar_repetido
# Out:
# 6

# %%
# Total de jogos com jogos consecutivos registrados
total_jogos_consecutivos = jogos_placar_repetido_com_proximo.shape[0]

# Jogos onde o placar não se repetiu
jogos_placar_nao_repetido = total_jogos_consecutivos - numero_jogos_placar_repetido
jogos_placar_nao_repetido
# Out:
# 31

# %% [markdown]
# Hipótese de que determinado repetir um placar em casa nas 2 rodadas seguintes é bem baixo

# %%
# Shiftando os placares para os próximos dois jogos
dados_2023['Placar_Proximo_2'] = dados_2023.groupby('Home')['Placar'].shift(-2)

# Verificando se o placar se repete por três jogos consecutivos
dados_2023['Placar_Repetido_3x'] = (dados_2023['Placar'] == dados_2023['Placar_Proxima_Rodada']) & (dados_2023['Placar'] == dados_2023['Placar_Proximo_2'])

# Probabilidade de um time repetir o mesmo placar em três jogos consecutivos
probabilidade_repetir_placar_3x = dados_2023['Placar_Repetido_3x'].mean() * 100
probabilidade_repetir_placar_3x
# Out:
# 1.3157894736842104

# %%
# Contando o número de jogos onde o placar se repetiu em três jogos consecutivos
numero_jogos_placar_repetido_3x = dados_2023['Placar_Repetido_3x'].sum()
numero_jogos_placar_repetido_3x
# Out:
# 1

# %%
# Filtrando os jogos onde o placar se repetiu em três jogos consecutivos
jogos_repetidos_3x = dados_2023[dados_2023['Placar_Repetido_3x']]

# Preparando os detalhes para exibição
jogos_repetidos_3x = jogos_repetidos_3x[['Season', 'Rodada', 'Date', 'Home', 'Away', 'Placar', 'Placar_Proxima_Rodada', 'Placar_Proximo_2']]
jogos_repetidos_3x.head()
# Out:
#       Season  Rodada        Date         Home       Away   Placar  \
# 4219    2023       4  09/05/2023  Corinthians  Fortaleza  1.0-1.0
#
#      Placar_Proxima_Rodada Placar_Proximo_2
# 4219               1.0-1.0          1.0-1.0

# %%
# Criando condição para jogos que repetiram o placar duas vezes mas não três vezes
dados_2023['Placar_Repetido_2x'] = (dados_2023['Placar'] == dados_2023['Placar_Proxima_Rodada']) & (dados_2023['Placar'] != dados_2023['Placar_Proximo_2'])

# Filtrando esses jogos específicos
jogos_repetidos_2x_nao_3x = dados_2023[dados_2023['Placar_Repetido_2x']]

# Preparando os detalhes para exibição
jogos_repetidos_2x_nao_3x = jogos_repetidos_2x_nao_3x[['Season', 'Rodada', 'Date', 'Home', 'Away', 'Placar', 'Placar_Proxima_Rodada', 'Placar_Proximo_2']]
jogos_repetidos_2x_nao_3x

#tem NAN pq como tá pegando só dos mandantes e tem poucos jogos de mandantes, é normal que tenha este comportamento
# Out:
#       Season  Rodada        Date           Home           Away   Placar  \
# 4181    2023       1  15/04/2023      Palmeiras         Cuiaba  2.0-1.0
# 4200    2023       3  29/04/2023       Coritiba      Sao Paulo  1.0-1.0
# 4209    2023       3  02/05/2023          Vasco          Bahia  0.0-1.0
# 4243    2023       7  20/05/2023     Bragantino   Athletico-PR  2.0-0.0
# 4249    2023       7  23/05/2023       Cruzeiro         Cuiaba  0.0-1.0
# 4257    2023       8  28/05/2023    Atletico-MG      Palmeiras  1.0-1.0
# 4259    2023       8  28/05/2023    Botafogo RJ     America MG  2.0-0.0
# 4262    2023       9  03/06/2023   Athletico-PR    Botafogo RJ  1.0-0.0
# 4263    2023       9  03/06/2023       Cruzeiro    Atletico-MG  0.0-1.0
# 4274    2023      10  11/06/2023    Botafogo RJ      Fortaleza  2.0-0.0
# 4303    2023      13  02/07/2023  Internacional       Cruzeiro  0.0-0.0
# 4307    2023      13  02/07/2023    Botafogo RJ          Vasco  2.0-0.0
# 4316    2023      14  09/07/2023     Bragantino      Sao Paulo  0.0-0.0
# 4328    2023      15  22/07/2023    Flamengo RJ     America MG  1.0-1.0
# 4341    2023      17  29/07/2023    Corinthians          Vasco  3.0-1.0
# 4353    2023      18  06/08/2023          Vasco         Gremio  1.0-0.0
# 4365    2023      19  14/08/2023      Palmeiras       Cruzeiro  1.0-0.0
# 4380    2023      21  27/08/2023     Bragantino         Cuiaba  2.0-0.0
# 4386    2023      21  27/08/2023      Palmeiras          Vasco  1.0-0.0
# 4389    2023      21  02/09/2023          Goias  Internacional  0.0-0.0
# 4393    2023      22  03/09/2023     Fluminense      Fortaleza  1.0-0.0
# 4406    2023      23  17/09/2023    Atletico-MG    Botafogo RJ  1.0-0.0
# 4419    2023      24  27/09/2023      Sao Paulo       Coritiba  2.0-1.0
# 4420    2023      25  30/09/2023    Flamengo RJ          Bahia  1.0-0.0
# 4429    2023      25  03/10/2023    Botafogo RJ          Goias  1.0-1.0
# 4432    2023      26  08/10/2023    Corinthians    Flamengo RJ  1.0-1.0
# 4458    2023      28  22/10/2023    Corinthians     America MG  1.0-1.0
# 4470    2023      30  28/10/2023      Palmeiras          Bahia  1.0-0.0
# 4472    2023      30  29/10/2023   Athletico-PR      Sao Paulo  1.0-1.0
# 4483    2023      31  02/11/2023    Botafogo RJ      Palmeiras  3.0-4.0
# 4486    2023      31  02/11/2023      Sao Paulo       Cruzeiro  1.0-0.0
# 4495    2023      32  07/11/2023         Santos         Cuiaba  0.0-0.0
# 4496    2023      32  08/11/2023     America MG       Coritiba  0.0-3.0
# 4502    2023      33  09/11/2023          Goias         Santos  0.0-1.0
# 4518    2023      34  23/11/2023      Fortaleza    Botafogo RJ  2.0-2.0
# 4538    2023      36  30/11/2023       Cruzeiro   Athletico-PR  1.0-1.0
#
#      Placar_Proxima_Rodada Placar_Proximo_2
# 4181               2.0-1.0          1.0-0.0
# 4200               1.0-1.0          1.0-0.0
# 4209               0.0-1.0          2.0-1.0
# 4243               2.0-0.0          1.0-0.0
# 4249               0.0-1.0          1.0-1.0
# 4257               1.0-1.0          2.0-1.0
# 4259               2.0-0.0              NaN
# 4262               1.0-0.0              NaN
# 4263               0.0-1.0              NaN
# 4274               2.0-0.0              NaN
# 4303               0.0-0.0              NaN
# 4307               2.0-0.0              NaN
# 4316               0.0-0.0              NaN
# 4328               1.0-1.0              NaN
# 4341               3.0-1.0              NaN
# 4353               1.0-0.0              NaN
# 4365               1.0-0.0              NaN
# 4380               2.0-0.0              NaN
# 4386               1.0-0.0              NaN
# 4389               0.0-0.0              NaN
# 4393               1.0-0.0              NaN
# 4406               1.0-0.0              NaN
# 4419               2.0-1.0              NaN
# 4420               1.0-0.0              NaN
# 4429               1.0-1.0              NaN
# 4432               1.0-1.0              NaN
# 4458               1.0-1.0              NaN
# 4470               1.0-0.0              NaN
# 4472               1.0-1.0              NaN
# 4483               3.0-4.0              NaN
# 4486               1.0-0.0              NaN
# 4495               0.0-0.0              NaN
# 4496               0.0-3.0              NaN
# 4502               0.0-1.0              NaN
# 4518               2.0-2.0              NaN
# 4538               1.0-1.0              NaN

# %% [markdown]
# Independente do Mando

# %%
# Criando uma nova coluna que identifica o time, independente de ser mandante ou visitante
dados_2023['Time'] = dados_2023['Home']
away_data = dados_2023[['Season', 'Rodada', 'Away', 'Placar']].rename(columns={'Away': 'Time'})
combined_data = pd.concat([dados_2023[['Season', 'Rodada', 'Time', 'Placar']], away_data])

# Ordenando por time e rodada
combined_data.sort_values(by=['Time', 'Season', 'Rodada'], inplace=True)

# Calculando o placar da próxima rodada para cada time
combined_data['Placar_Proxima_Rodada'] = combined_data.groupby('Time')['Placar'].shift(-1)

# Verificando se o placar se repete
combined_data['Placar_Repetido'] = combined_data['Placar'] == combined_data['Placar_Proxima_Rodada']

# Calculando a probabilidade de um time repetir o mesmo placar na próxima rodada, independente do mando
probabilidade_repetir_placar_indep = combined_data['Placar_Repetido'].mean() * 100
probabilidade_repetir_placar_indep
# Out:
# 7.236842105263158
